# %% [markdown]
# # Drawing geometric shapes on an image using opencv library

# %% [markdown]
# Opencv have various various types of drawing function to draw dfferent geometric shapes and write text on an image. In this tutorial we are going to see functions to draw shapes like line, Rectangle, circle, Ellips and polygon.
#
# opencv drawing functions are following:
#
# **cv2.line()** : This function is used to draw line on an image.
# **cv2.rectangle()** : This function is used  to draw rectangle on an image.
# **cv2.circle()** : This function is used to draw circle on an image.
# **cv2.putText()** : This function is used to write text on image.

# %% [markdown]
# # Importing  opencv library

# %%
import cv2
import numpy as np

# %% [markdown]
# ## 1. Drawing a line on an image

# %% [markdown]
# Opencv provides cv2.line() function for drawing a line on an image.
# ## <font color="Green"><h4 align="left">Syntax</h4></font>
#
# **cv2.line (img,pt1,pt2,color,thickness = 1,lineType = LINE_8)**
#
# Draws a line segment connecting two points.
#
# The function line draws the line segment between pt1 and pt2 points in the image.
#
# **Parameters**
#
#    **img**:	Image where line will drawn.
#
#    **pt1**:	First point or starting coordinate of the line segment.
#
#    **pt2**:	Second point or ending coordinate  of the line segment.
#
#    **color**:	Line color.Color of the shape. for BGR, pass it as a tuple, eg: (255,0,0) for blue. For grayscale, just pass the scalar value.
#
#    **thickness**:Thickness of the lines.thickness=10 means thickness of 10 pixels
#
#    **lineType**:	Type of the line. Different type of line is 4 connected, 8-connected, anti-aliased line etc. By default, it is 8-connected. cv.LINE_AA gives anti-aliased line which looks great for curves.
#
#
#
# If you want to know what is 8 connected then read this tutorial
# http://www.imageprocessingplace.com/downloads_V3/root_downloads/tutorials/contour_tracing_Abeer_George_Ghuneim/connect.html

# %% [markdown]
# ## Example1: Drawing line using cv2.line()

# %%
#Load image
img_line=cv2.imread("image.jpg")

# %%
#Display image
window_name='imagefirst'
cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
cv2.imshow(window_name,img_line)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![Screenshot%20from%202020-03-20%2017-55-11.png](attachment:Screenshot%20from%202020-03-20%2017-55-11.png)

# %%
#Draw line
#line is red with thickness of 10 pixels
cv2.line(img_line,(0,0),(500,500),(0,255,0),10)
# Out:
# array([[[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
#Display image
window_name='imagefirst_line'
cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
cv2.imshow(window_name,img_line)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![Screenshot%20from%202020-03-20%2017-55-34.png](attachment:Screenshot%20from%202020-03-20%2017-55-34.png)

# %% [markdown]
# ## Example2: Drawing a red line with more thickness using cv2.line()

# %%
#Load image
img_line_second=cv2.imread("image.jpg")

# %%
#Display image
window_name='imagesecond'
cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
cv2.imshow(window_name,img_line_second)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![Screenshot%20from%202020-03-20%2017-56-21.png](attachment:Screenshot%20from%202020-03-20%2017-56-21.png)

# %%
#Draw line
#Red Lines with thickness of 20 pixels
cv2.line(img_line_second,(0,0),(1000,1000),(0,0,255),20)
# Out:
# array([[[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
#Display image
window_name='imagesecond_line'
cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
cv2.imshow(window_name,img_line_second)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![Screenshot%20from%202020-03-20%2017-57-00.png](attachment:Screenshot%20from%202020-03-20%2017-57-00.png)

# %% [markdown]
# # 2. Drawing a rectangle on an image: cv2.rectangle()

# %% [markdown]
# Opencv provides **cv2.rectangle()** function for drawing a rectangle on an image.
#
# ## <font color="Green"><h4 align="left">Syntax</h4></font>
#
# **cv2.rectangle(img, pt1, pt2, color,thickness,lineType)**
#
# The function cv2.rectangle draws a rectangle outline or a filled rectangle whose two opposite corners are pt1 and pt2.
#
# Parameters
#     **img**:  Image on which rectangle to be drawn.
#
#    **pt1**: Vertex of the top-left corner rectangle.
#
#    **pt2**	Vertex of the Bottom-right corner of rectangle i.e opposite to pt1.
#
#    **color**: Rectangle color (BGR) or brightness (grayscale image).
#
#    **thickness**:Thickness of lines that make up the rectangle. Negative values, like FILLED, mean that the function has to draw a filled rectangle.
#
#    **lineType**:Type of the line. Same as above

# %% [markdown]
# ## Example1: Drawing rectangle using cv2.rectangle()

# %%
#Load image
img_rectangle=cv2.imread("image.jpg")

# %%
#Display image
window_name='imagewithoutrectangle'
cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
cv2.imshow(window_name,img_rectangle)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![Screenshot%20from%202020-03-20%2017-58-17.png](attachment:Screenshot%20from%202020-03-20%2017-58-17.png)

# %%
cv2.rectangle(img_rectangle,(384,0),(1024,1024),(255,0,0),3)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
#Display image
window_name='imagewithRectangle'
cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
cv2.imshow(window_name,img_rectangle)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![Screenshot%20from%202020-03-20%2017-58-48.png](attachment:Screenshot%20from%202020-03-20%2017-58-48.png)

# %% [markdown]
# ## Example2: Drawing a yellow rectangle with more thickness using cv2.rectangle()

# %%
#Load image
img_rectangle_second=cv2.imread("image.jpg")

# %%
#Display image
window_name='imageSecondwithoutRectangle'
cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
cv2.imshow(window_name,img_rectangle_second)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![Screenshot%20from%202020-03-20%2017-59-24.png](attachment:Screenshot%20from%202020-03-20%2017-59-24.png)

# %%
#Draw rectangle
cv2.rectangle(img_rectangle_second,(500,0),(1024,1024),(0,255,255),20)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
#Display image
window_name='imageSecond_WithRectangle'
cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
cv2.imshow(window_name,img_rectangle_second)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![Screenshot%20from%202020-03-20%2018-00-13.png](attachment:Screenshot%20from%202020-03-20%2018-00-13.png)

# %% [markdown]
# ## Example3:Drawing a filled yellow rectangle using cv2.rectangle()

# %%
#Load image
img_rectangle_third=cv2.imread("image.jpg")

# %%
#Display image
window_name='ImageThirdWithoutRectangle'
cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
cv2.imshow(window_name,img_rectangle_third)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![Screenshot%20from%202020-03-20%2018-01-14.png](attachment:Screenshot%20from%202020-03-20%2018-01-14.png)

# %% [markdown]
# ### To draw filled rectangle you have to pass thickness=-1

# %%
cv2.rectangle(img_rectangle_third,(500,0),(1024,1024),(0,255,255),-1)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
#Display image
window_name='imageThirdWithRectangle'
cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
cv2.imshow(window_name,img_rectangle_third)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![Screenshot%20from%202020-03-20%2018-02-03.png](attachment:Screenshot%20from%202020-03-20%2018-02-03.png)

# %% [markdown]
# # 2. Drawing a circle on an image: cv2.circle()

# %% [markdown]
# Opencv provides **cv2.circle()** function for drawing a circle on an image.
#
# We know that in general We need center coordinates and radius to draw a circle.
#
# ## <font color="Green"><h4 align="left">Syntax</h4></font>
#
# **cv2.circle(	img, center, radius, colorthickness,lineType)**
#
# **Parameters**
#
#    **img**	Image where the circle is drawn.
#
#    **center**	Center of the circle.
#
#    **radius**	Radius of the circle.
#
#    **color**	Colour of cirlce.
#
#    **thickness**	Thickness of the circle outline.
#
#    **lineType**	Type of the circle boundary.

# %% [markdown]
# ## Example1:  Drawing circle using cv2.circle()

# %%
#Load image
img_circle=cv2.imread("image.jpg")

# %%
#Display image
window_name='ImageFirstWithoutCircle'
cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
cv2.imshow(window_name,img_circle)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![Screenshot%20from%202020-03-20%2018-03-39.png](attachment:Screenshot%20from%202020-03-20%2018-03-39.png)

# %%
#Draw circle
cv2.circle(img_circle,(1024,1024), 150, (0,0,255), 20)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
#Display image
window_name='ImageFirstWithCircle'
cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
cv2.imshow(window_name,img_circle)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![Screenshot%20from%202020-03-20%2018-04-25.png](attachment:Screenshot%20from%202020-03-20%2018-04-25.png)

# %% [markdown]
# ## Example2:Drawing a filled yellow cirlce using cv2.circle()

# %%
#Load image
img_circle_second=cv2.imread("image.jpg")

# %%
#Draw filled circles
cv2.circle(img_circle_second,(1024,1024), 150, (0,0,255), -1)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
#Display image
window_name='imageSecondWithCircles'
cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
cv2.imshow(window_name,img_circle_second)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![Screenshot%20from%202020-03-20%2018-06-17.png](attachment:Screenshot%20from%202020-03-20%2018-06-17.png)

# %% [markdown]
# # 2. Drawing an ellipse on an image:cv2.ellipse()

# %% [markdown]
# Opencv provides **cv2.ellipse()** function for drawing a ellipse on an image.
#
# ## <font color="Green"><h4 align="left">Syntax</h4></font>
#
# cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color, thickness, lineType)
#
# Parameters
#
#    **img**: Image where the ellipse is drawn.
#
#    **center**  center location (x,y).
#
#    **axes**:   argument is axes lengths (major axis length, minor axis length)
#
#    **angle** : angle is the angle of rotation of ellipse in anti-clockwise direction.
#
#    **startAngle and endAngle** : startAngle and endAngle denotes the starting and ending of ellipse arc measured in clockwise direction from major axis. i.e. giving values 0 and 360 gives the full ellipse.
#
#    **color**	colour of ellipse .
#
#    **thickness**	Thickness of the ellipse arc outline
#
#    **lineType**	Type of the ellipse boundary.This argument is similar to previous one
#
#
# **To draw the ellipse, we need to pass several arguments incomparison of other shapes**.

# %% [markdown]
# ## Example1:  Drawing ellipse using cv2.ellipse()

# %%
#Load image
img_ellipse=cv2.imread("image.jpg")

# %%
#Display image
window_name='imageFirstWithoutEllipse'
cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
cv2.imshow(window_name,img_ellipse)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![Screenshot%20from%202020-03-20%2018-07-08.png](attachment:Screenshot%20from%202020-03-20%2018-07-08.png)

# %%
#Draw ellipse
cv2.ellipse(img_ellipse,(256,256),(100,50),0,0,180,255,20)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
#Display image
window_name='imageFirstWithEllipse'
cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
cv2.imshow(window_name,img_ellipse)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![Screenshot%20from%202020-03-20%2018-07-58.png](attachment:Screenshot%20from%202020-03-20%2018-07-58.png)

# %% [markdown]
# ## Example2:Drawing a filled yellow ellipse using cv2.ellipse()

# %%
#Load image
img_ellipse_second=cv2.imread("image.jpg")

# %%
#Display image
window_name='imageSecondWithoutEllipse'
cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
cv2.imshow(window_name,img_ellipse_second)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![Screenshot%20from%202020-03-20%2018-09-08.png](attachment:Screenshot%20from%202020-03-20%2018-09-08.png)

# %%
#Draw filled ellipse
cv2.ellipse(img_ellipse_second,(256,256),(100,50),0,0,180,(0,255,255),-1)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %% [markdown]
# #Display image
# window_name='ImageSecondWithEllipse'
# cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
# cv2.imshow(window_name,img_ellipse_second)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %% [markdown]
# ![Screenshot%20from%202020-03-20%2018-09-51.png](attachment:Screenshot%20from%202020-03-20%2018-09-51.png)

# %% [markdown]
# # Drawing Polygon:cv2.polylines()

# %% [markdown]
# Opencv provides cv2.polylines() function for drawing a ploygon on an image.
#
# ## <font color="Green"><h4 align="left">Syntax</h4></font>
#
# **cv2.polylines(img, pts, isClosed, color, thickness,lineType)**
#
# **Parameters**
#
#    **img**	: Image.
#
#    **pts**:	Array of polygonal curves. To draw a polygon, first you need coordinates of vertices. Make those points into an array of shape ROWSx1x2 where ROWS are number of vertices and it should be of type int32.
#
#    **isClosed**	:Flag indicating whether the drawn polylines are closed or not. If they are closed, the function draws a line from the last vertex of each curve to its first vertex.
#
#    **color**:	Polyline color.
#
#    **thickness**: Thickness of the polyline edges.
#
#    **lineType**	:Type of the line segments

# %% [markdown]
# ## Example:  Drawing polygones using cv2.polylines()

# %%
#Load image
img_polygon=cv2.imread("image.jpg")

# %%
#Display image
window_name='ImageFirstWithoutPolygon'
cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
cv2.imshow(window_name,img_polygon)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![Screenshot%20from%202020-03-20%2018-11-41.png](attachment:Screenshot%20from%202020-03-20%2018-11-41.png)

# %%
#Draw polygon on the coordinates pts
pts = np.array([[100,50],[200,300],[700,200],[500,100]], np.int32)
pts = pts.reshape((-1,1,2))
cv2.polylines(img_polygon,[pts],True,(0,0,255),20)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
#Display image
window_name='ImageFirstWithPolygon'
cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
cv2.imshow(window_name,img_polygon)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![Screenshot%20from%202020-03-20%2018-13-00.png](attachment:Screenshot%20from%202020-03-20%2018-13-00.png)

# %% [markdown]
# ## Example2:  Drawing polygons using cv2.polylines()

# %% [markdown]
# **If third argument(isClosed) is False, you will get a polylines joining all the points, not a closed shape.**

# %%
#Load image
img_polygon_second=cv2.imread("image.jpg")

# %%
#if isclosed=False
pts = np.array([[100,50],[200,300],[700,200],[500,100]], np.int32)
pts = pts.reshape((-1,1,2))
cv2.polylines(img_polygon_second,[pts],False,(0,0,255),20)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
#Display image
window_name='imagefirst'
cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
cv2.imshow(window_name,img_polygon_second)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![Screenshot%20from%202020-03-20%2018-13-49.png](attachment:Screenshot%20from%202020-03-20%2018-13-49.png)

# %% [markdown]
# # PuttingText :cv2.putText()

# %% [markdown]
# Opencv provides cv2.putText() function to write a text on an image.
#
# ## <font color="Green"><h4 align="left">Syntax</h4></font>
#
#
# **cv2.putText(img, text, org, fontFace, fontScale, color,thickness,lineType,bottomLeftOrigin)**
#
# **Parameters**
#     **img**	The image on which to put text
#
#    **text**	Text string to be written.
#
#    **org**	Bottom-left corner of the text string in the image i.e Position coordinates of where you want put the string
#
#    **fontFace**	Font type.
#
#    **fontScale**	Font scale factor that is multiplied by the font-specific base size.
#
#    **color**	Text color.
#
#    **thickness**	Thickness of the lines used to draw a text.
#
#    **lineType**	Line type.
#
#    **bottomLeftOrigin**	When true, the image data origin is at the bottom-left corner. Otherwise, it is at the top-left corner.

# %% [markdown]
# ## Example1: Putting Text using cv2

# %%
#Load image
img_first=cv2.imread("image.jpg")

# %%
#Display image
window_name='ImageFirstWithoutText'
cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
cv2.imshow(window_name,img_first)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img_first,'PUT TEXT',(10,500), font, 4,(255,0,0),10,cv2.LINE_AA)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
#Display image
window_name='imagefirstWithText'
cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
cv2.imshow(window_name,img_first)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![Screenshot%20from%202020-03-20%2018-16-42.png](attachment:Screenshot%20from%202020-03-20%2018-16-42.png)
